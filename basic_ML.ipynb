# %% [markdown]
# ### Supervised Learning
#
# it use labeled data to train models
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# #### classification
#
# Accuracy = number of correct predictions / total number of predictions
#
# * it use when target classes are well balance in quantity
#
# Recall = true positive / (true positive + true negative)
#
# precision = true positive /(true positive + false positive)
#
# F1-Score = 2* precision * recall /(precision *+ recall)
#
# ##### confusion matrix
# ![image-3.png](attachment:image-3.png)
#
# ### Regression
#
# * mean absolute Error - mean of the absolute value of error
#
# ![image-4.png](attachment:image-4.png)
#
# * mean squared Error - mean of the squared error
#
# ![image-5.png](attachment:image-5.png)
#
# * Root Mean Square Error - this is root of the mse.
#
# ![image-6.png](attachment:image-6.png)
